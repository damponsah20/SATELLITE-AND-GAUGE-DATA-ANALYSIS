# %% [markdown]
# COMPARISON OF SATELLITE AND GAUGE DATA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
assignment = pd.read_excel("Data.xlsx")
assignment
# Out:
#        YEAR  MONTH  GAUGE DATA   SATELLITE DATA
# 0    1998.0    1.0    20.903946       12.799863
# 1    1998.0    2.0    27.162743       25.698927
# 2    1998.0    3.0    28.503807       20.155447
# 3    1998.0    4.0    94.114746      110.638329
# 4    1998.0    5.0   121.339172      142.182053
# ..      ...    ...          ...             ...
# 175  2012.0    8.0    77.245155      141.330063
# 176  2012.0    9.0   168.770508      172.583878
# 177  2012.0   10.0   142.981079      111.247154
# 178  2012.0   11.0    42.880787       50.230442
# 179  2012.0   12.0    16.743238       50.081524
#
# [180 rows x 4 columns]

# %%
assignment['SATELLITE DATA'].head(12)
# Out:
# 0      12.799863
# 1      25.698927
# 2      20.155447
# 3     110.638329
# 4     142.182053
# 5     136.204590
# 6      98.334167
# 7     128.431046
# 8     146.000687
# 9     130.585861
# 10     25.761711
# 11     14.272449
# Name: SATELLITE DATA, dtype: float64

# %%
assignment['GAUGE DATA ']
# Out:
# 0       20.903946
# 1       27.162743
# 2       28.503807
# 3       94.114746
# 4      121.339172
#           ...
# 175     77.245155
# 176    168.770508
# 177    142.981079
# 178     42.880787
# 179     16.743238
# Name: GAUGE DATA , Length: 180, dtype: float64

# %%
assignment['GAUGE DATA '].tail(12)
# Out:
# 168      9.710544
# 169     34.969418
# 170     42.628529
# 171    100.341156
# 172    149.931412
# 173    180.057922
# 174    121.844231
# 175     77.245155
# 176    168.770508
# 177    142.981079
# 178     42.880787
# 179     16.743238
# Name: GAUGE DATA , dtype: float64

# %%
mine= pd.read_excel("Data.xlsx").iloc[24:48]
mine
# Out:
#       YEAR  MONTH  GAUGE DATA   SATELLITE DATA
# 24  2000.0    1.0    35.072559       16.304209
# 25  2000.0    2.0    15.144871        6.245264
# 26  2000.0    3.0    49.737408       57.861607
# 27  2000.0    4.0    95.977959      118.029701
# 28  2000.0    5.0   127.628151      135.199814
# 29  2000.0    6.0   202.719559      168.975998
# 30  2000.0    7.0   132.480835      129.058853
# 31  2000.0    8.0   129.781754      144.838150
# 32  2000.0    9.0   174.841248      159.618912
# 33  2000.0   10.0    80.610344       93.246094
# 34  2000.0   11.0    29.478745       19.526628
# 35  2000.0   12.0    19.226868        3.140524
# 36  2001.0    1.0    10.879764        9.663283
# 37  2001.0    2.0    17.226749        8.844838
# 38  2001.0    3.0    58.188282       26.826067
# 39  2001.0    4.0   121.773521      144.112473
# 40  2001.0    5.0   116.886284      140.960190
# 41  2001.0    6.0   164.590561      156.344894
# 42  2001.0    7.0   117.021400      113.545998
# ...

# %%
import pandas as pd
data=pd.read_excel("C:/Users/AMPONSAH DANIEL/Desktop/PYTHON CLASS/Data.xlsx")
data
# Out:
#        YEAR  MONTH  GAUGE DATA   SATELLITE DATA
# 0    1998.0    1.0    20.903946       12.799863
# 1    1998.0    2.0    27.162743       25.698927
# 2    1998.0    3.0    28.503807       20.155447
# 3    1998.0    4.0    94.114746      110.638329
# 4    1998.0    5.0   121.339172      142.182053
# ..      ...    ...          ...             ...
# 175  2012.0    8.0    77.245155      141.330063
# 176  2012.0    9.0   168.770508      172.583878
# 177  2012.0   10.0   142.981079      111.247154
# 178  2012.0   11.0    42.880787       50.230442
# 179  2012.0   12.0    16.743238       50.081524
#
# [180 rows x 4 columns]

# %% [markdown]
# YEARS TO USE; 2000 AND 2001

# %%
both_years=pd.read_excel("C:/Users/AMPONSAH DANIEL/Desktop/PYTHON CLASS/Data.xlsx").iloc[24:48]
both_years
# Out:
#       YEAR  MONTH  GAUGE DATA   SATELLITE DATA
# 24  2000.0    1.0    35.072559       16.304209
# 25  2000.0    2.0    15.144871        6.245264
# 26  2000.0    3.0    49.737408       57.861607
# 27  2000.0    4.0    95.977959      118.029701
# 28  2000.0    5.0   127.628151      135.199814
# 29  2000.0    6.0   202.719559      168.975998
# 30  2000.0    7.0   132.480835      129.058853
# 31  2000.0    8.0   129.781754      144.838150
# 32  2000.0    9.0   174.841248      159.618912
# 33  2000.0   10.0    80.610344       93.246094
# 34  2000.0   11.0    29.478745       19.526628
# 35  2000.0   12.0    19.226868        3.140524
# 36  2001.0    1.0    10.879764        9.663283
# 37  2001.0    2.0    17.226749        8.844838
# 38  2001.0    3.0    58.188282       26.826067
# 39  2001.0    4.0   121.773521      144.112473
# 40  2001.0    5.0   116.886284      140.960190
# 41  2001.0    6.0   164.590561      156.344894
# 42  2001.0    7.0   117.021400      113.545998
# ...

# %% [markdown]
# FOR THE YEAR 2000

# %%
year_2000=pd.read_excel("C:/Users/AMPONSAH DANIEL/Desktop/PYTHON CLASS/Data.xlsx").iloc[24:36]
year_2000
# Out:
#       YEAR  MONTH  GAUGE DATA   SATELLITE DATA
# 24  2000.0    1.0    35.072559       16.304209
# 25  2000.0    2.0    15.144871        6.245264
# 26  2000.0    3.0    49.737408       57.861607
# 27  2000.0    4.0    95.977959      118.029701
# 28  2000.0    5.0   127.628151      135.199814
# 29  2000.0    6.0   202.719559      168.975998
# 30  2000.0    7.0   132.480835      129.058853
# 31  2000.0    8.0   129.781754      144.838150
# 32  2000.0    9.0   174.841248      159.618912
# 33  2000.0   10.0    80.610344       93.246094
# 34  2000.0   11.0    29.478745       19.526628
# 35  2000.0   12.0    19.226868        3.140524

# %% [markdown]
# PLOTTING GRAPH FOR THE YEAR 2000

# %%
import matplotlib.pyplot as plt

# %%
gauge_data = year_2000['GAUGE DATA ']
satellite_data=year_2000['SATELLITE DATA']
MONTHS = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
plt.plot(MONTHS,gauge_data,color='r',marker='o',label='gauge data');

plt.xlabel('MONTHS')
plt.ylabel('gauge data');
plt.legend()
plt.twinx()
plt.plot(MONTHS,satellite_data,color='b',marker='o',label='satellite data');
plt.ylabel('satellite data')
plt.legend()
plt.title('A GRAPH OF MONTHLY GAUGE AND SATELLITE DATA FOR THE YEAR 2000');

# %% [markdown]
# FOR THE YEAR 2001

# %%
year_2001=pd.read_excel("C:/Users/AMPONSAH DANIEL/Desktop/PYTHON CLASS/Data.xlsx").iloc[36:48]
year_2001
# Out:
#       YEAR  MONTH  GAUGE DATA   SATELLITE DATA
# 36  2001.0    1.0    10.879764        9.663283
# 37  2001.0    2.0    17.226749        8.844838
# 38  2001.0    3.0    58.188282       26.826067
# 39  2001.0    4.0   121.773521      144.112473
# 40  2001.0    5.0   116.886284      140.960190
# 41  2001.0    6.0   164.590561      156.344894
# 42  2001.0    7.0   117.021400      113.545998
# 43  2001.0    8.0   103.713341      135.959091
# 44  2001.0    9.0   162.746719      183.998672
# 45  2001.0   10.0    67.564552       65.681831
# 46  2001.0   11.0    29.914223       26.156105
# 47  2001.0   12.0    19.911196        6.254922

# %% [markdown]
# PLOTTING GRAPH FOR THE YEAR 2001

# %%
gauge_data = year_2001['GAUGE DATA ']
satellite_data=year_2001['SATELLITE DATA']
MONTHS = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
plt.plot(MONTHS,gauge_data,color='r',marker='o',label='gauge data');

plt.xlabel('MONTHS')
plt.ylabel('gauge data');
plt.twinx()
plt.plot(MONTHS,satellite_data,color='b',marker='o',label='satellite data');
plt.ylabel('satellite data')

plt.title('A GRAPH OF MONTHLY GAUGE AND SATELLITE DATA FOR THE YEAR 2001');
plt.legend();
